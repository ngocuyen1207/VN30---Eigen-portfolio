# %%
from vnquant.DataLoader import DataLoader
from vnquant import Plot
from vnquant import utils
import seaborn as sns
import pandas as pd
import vnquant.DataLoader as web
import matplotlib.pyplot as plt
from matplotlib.widgets import Slider, Button
import pandas_datareader.data as pdreader
import yfinance as yf
  
import math
import pandas as pd
import numpy as np
import datetime as dt
import matplotlib.pyplot as plt
from matplotlib import style
import seaborn as sns
from scipy.stats import randint as sp_randint

from sklearn.decomposition import PCA

style.use("ggplot")

# %%
df = pd.read_excel(r'C:\Users\VV765QV\OneDrive - EY\Training\Leave\Data Science\VN30\VN30.xlsx')
df.dropna(inplace=True)
# Out:
# 2021-09-12 21:52:00,703 : INFO : NumExpr defaulting to 8 threads.

# %%
df.set_index('date')
# Out:
#               ACB    BID   BVH    CTG    FPT    GAS    GVR    HDB   HPG  \
# date
# 2018-06-04  42.00  30.50  94.9  27.95  47.25   92.3   8.80  43.00  60.0
# 2018-06-05  41.70  30.40  94.9  28.40  47.80   98.7   8.40  43.20  59.0
# 2018-06-06  43.30  31.80  95.1  28.95  48.50  102.9   8.40  43.20  60.8
# 2018-06-07  42.40  31.20  95.9  28.35  47.80   99.6   8.80  44.60  61.9
# 2018-06-08  43.10  31.50  95.9  28.55  47.95   97.5   8.40  43.40  61.3
# ...           ...    ...   ...    ...    ...    ...    ...    ...   ...
# 2021-08-25  32.45  39.45  52.7  32.15  91.90   87.3  35.20  33.80  48.4
# 2021-08-26  31.95  38.60  52.6  31.20  91.40   86.3  35.50  26.85  47.7
# 2021-08-27  31.75  38.70  53.4  31.15  92.00   87.0  37.40  26.50  47.6
# 2021-08-30  32.15  39.45  55.0  32.30  92.20   87.5  37.60  26.70  48.7
# 2021-08-31  32.00  38.95  57.0  31.80  92.40   89.4  38.75  25.95  49.3
#
#               KDH  ...    STB     TCB    TPB   VCB    VHM    VIC    VJC  \
# ...

# %% [markdown]
# # 1. Data & methodology

# %% [markdown]
# ## 1.1. Selection of the sectors and stocks

# %% [markdown]
# - All VN30 stocks are chosen

# %% [markdown]
# ## 1.2. Data acquisition

# %% [markdown]
# - Please refer to file 'Extract data - VN30.ipynb'

# %% [markdown]
# ## 1.3. Computation of return and volatility

# %%
# Daily return - Pct change in close price daily
daily_return = df.select_dtypes(include=['number']).pct_change()
daily_return
# Out:
#            ACB       BID       BVH       CTG       FPT       GAS       GVR  \
# 3081       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 3082 -0.007143 -0.003279  0.000000  0.016100  0.011640  0.069339 -0.045455
# 3083  0.038369  0.046053  0.002107  0.019366  0.014644  0.042553  0.000000
# 3084 -0.020785 -0.018868  0.008412 -0.020725 -0.014433 -0.032070  0.047619
# 3085  0.016509  0.009615  0.000000  0.007055  0.003138 -0.021084 -0.045455
# ...        ...       ...       ...       ...       ...       ...       ...
# 3891  0.004644  0.001269  0.001901 -0.018321  0.000000  0.015116  0.035294
# 3892 -0.015408 -0.021546 -0.001898 -0.029549 -0.005441 -0.011455  0.008523
# 3893 -0.006260  0.002591  0.015209 -0.001603  0.006565  0.008111  0.053521
# 3894  0.012598  0.019380  0.029963  0.036918  0.002174  0.005747  0.005348
# 3895 -0.004666 -0.012674  0.036364 -0.015480  0.002169  0.021714  0.030585
#
# ...
